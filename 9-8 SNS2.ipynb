# %%
# 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
iris = sns.load_dataset('iris')
tips = sns.load_dataset('tips')

# %%
# head; what species
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#pair plot; correlation?
sns.pairplot(iris, hue = 'species',palette='prism')

# %%
#petal length and petal width have a strong correlation
#However, BIAS is BAD

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
# draw the same for iris
sns.lmplot(x='sepal_width', y='sepal_length', data=iris)

# %%
# draw the same for iris
sns.lmplot(x='sepal_length', y='sepal_width', data=iris)

# %%
# draw the same for iris
sns.lmplot(x='petal_width', y='petal_length', data=iris)

# %%
# draw the same for iris
sns.lmplot(x='petal_length', y='petal_width', data=iris)

# %%
#Data vs Survival
#Box plot for titanic based on class and age (what do I learn?)
#Heat map of titan data
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 911 data, counts by 'zip' (zip code)
# How many unique titles? what are they?
#Access the value of the time timeStamp attribute
